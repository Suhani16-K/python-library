# %% [markdown]
# <a href="https://colab.research.google.com/github/Suhani16-K/python-library/blob/main/Untitled18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### What is Pandas
#
# Pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool,
# built on top of the Python programming language.
#
# https://pandas.pydata.org/about/index.html

# %% [markdown]
# ### Pandas Series
#
# A Pandas Series is like a column in a table. It is a 1-D array holding data of any type.

# %% [markdown]
# ### Importing Pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Series from lists

# %%
#String
country = ['India','Pakistan','USA','Nepal','Srilanka']
pd.Series(country)
# Out:
# 0       India
# 1    Pakistan
# 2         USA
# 3       Nepal
# 4    Srilanka
# dtype: object

# %%
# integers
runs=[43,55,65,76,87,89,90]
pd.Series(runs)
# Out:
# 0    43
# 1    55
# 2    65
# 3    76
# 4    87
# 5    89
# 6    90
# dtype: int64

# %%
# custom index
marks=[43,54,56,45]
subjects = ['maths','english','science','hindi']

pd.Series(marks,index=subjects)
# Out:
# maths      43
# english    54
# science    56
# hindi      45
# dtype: int64

# %%
# setting a name
marks=pd.Series(marks,index=subjects,name='Suhani ke marks')
marks
# Out:
# maths      43
# english    54
# science    56
# hindi      45
# Name: Suhani ke marks, dtype: int64

# %% [markdown]
# ### Series from dict

# %%
marks  = {'maths':67,'english':65,'science':87,'hindi':78}
ms=pd.Series(marks,name='suhani ke number')
ms
# Out:
# maths      67
# english    65
# science    87
# hindi      78
# Name: suhani ke number, dtype: int64

# %% [markdown]
# ### Series Attributes

# %%
# size
marks.size
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_12510/1492173072.py in <cell line: 0>()
#       1 # size
# ----> 2 marks.size
#
# AttributeError: 'dict' object has no attribute 'size'

# %%
# dtype
marks.dtype
# Out:
# dtype('int64')

# %%
# name
marks.name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_12510/3436472246.py in <cell line: 0>()
#       1 # name
# ----> 2 marks.name
#
# AttributeError: 'dict' object has no attribute 'name'

# %%
# is_unique
marks.is_unique
# Out:
# True

# %%
# index
marks.index
# Out:
# Index(['maths', 'english', 'science', 'hindi'], dtype='object')

# %%
runs.index
# Out:
# <function list.index(value, start=0, stop=9223372036854775807, /)>

# %%
# values
marks.values
# Out:
# array([43, 54, 56, 45])

# %% [markdown]
# ### Series using read_csv

# %%
# with one col
subs = pd.read_csv('file:///C:/Users/LENOVO/Downloads/archive/',squeeze=True)
subs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_12510/1229231808.py in <cell line: 0>()
#       1 # with one col
# ----> 2 subs = pd.read_csv('file:///C:/Users/LENOVO/Downloads/archive/',squeeze=True)
#       3 subs
#
# NameError: name 'pd' is not defined

# %%
# with 2 cols

# %% [markdown]
# ### Series methods
